# %%
pip install seaborn
# Out:
# ...
#   Using cached matplotlib-3.5.3-cp37-cp37m-win_amd64.whl.metadata (6.7 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl.metadata (785 bytes)
# ...
#   Using cached fonttools-4.38.0-py3-none-any.whl.metadata (138 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp37-cp37m-win_amd64.whl.metadata (6.5 kB)
# ...
#   Using cached Pillow-9.5.0-cp37-cp37m-win_amd64.whl.metadata (9.7 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...
#    ---------------------------------------- 293.3/293.3 kB 9.1 MB/s eta 0:00:00
# Using cached matplotlib-3.5.3-cp37-cp37m-win_amd64.whl (7.2 MB)
# Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Using cached kiwisolver-1.4.5-cp37-cp37m-win_amd64.whl (55 kB)
# Using cached Pillow-9.5.0-cp37-cp37m-win_amd64.whl (2.5 MB)
# Using cached pyparsing-3.1.4-py3-none-any.whl (104 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# c:\users\moham\onedrive\bureau\table\.venv\lib\site-packages\IPython\core\interactiveshell.py:3553: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
# Only USA races, 50km or 50mi, 2020

# %%
# Step 1: show 50mi or 50km

# %%
df[df["Event distance/length"] == '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[df["Event distance/length"] == '50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
# combine 50mi / 50km

# %%
df[df["Event distance/length"].isin(['50km', '50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df["Event distance/length"].isin(['50km', '50mi']))   & (df["Year of event"] == 2020) ]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[df["Event name"] == "Bison Ultra-Trail 50 (POL)"]
# Out:
#          Year of event Event dates                  Event name  \
# 2762138           2020  03.10.2020  Bison Ultra-Trail 50 (POL)
# 2762139           2020  03.10.2020  Bison Ultra-Trail 50 (POL)
# 2762140           2020  03.10.2020  Bison Ultra-Trail 50 (POL)
# 2762141           2020  03.10.2020  Bison Ultra-Trail 50 (POL)
# 2762142           2020  03.10.2020  Bison Ultra-Trail 50 (POL)
# ...                ...         ...                         ...
# 3495934           2022  01.10.2022  Bison Ultra-Trail 50 (POL)
# 3495935           2022  01.10.2022  Bison Ultra-Trail 50 (POL)
# 3495936           2022  01.10.2022  Bison Ultra-Trail 50 (POL)
# 3495937           2022  01.10.2022  Bison Ultra-Trail 50 (POL)
# 3495938           2022  01.10.2022  Bison Ultra-Trail 50 (POL)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2762138                  50km                        271           3:58:33 h
# ...

# %%
df[df["Event name"] == "Bison Ultra-Trail 50 (POL)"]["Event name"].str.split('(')
# Out:
# 2762138    [Bison Ultra-Trail 50 , POL)]
# 2762139    [Bison Ultra-Trail 50 , POL)]
# 2762140    [Bison Ultra-Trail 50 , POL)]
# 2762141    [Bison Ultra-Trail 50 , POL)]
# 2762142    [Bison Ultra-Trail 50 , POL)]
#                        ...
# 3495934    [Bison Ultra-Trail 50 , POL)]
# 3495935    [Bison Ultra-Trail 50 , POL)]
# 3495936    [Bison Ultra-Trail 50 , POL)]
# 3495937    [Bison Ultra-Trail 50 , POL)]
# 3495938    [Bison Ultra-Trail 50 , POL)]
# Name: Event name, Length: 794, dtype: object

# %%
df[df["Event name"] == "Bison Ultra-Trail 50 (POL)"]["Event name"].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 2762138    POL
# 2762139    POL
# 2762140    POL
# 2762141    POL
# 2762142    POL
#           ...
# 3495934    POL
# 3495935    POL
# 3495936    POL
# 3495937    POL
# 3495938    POL
# Name: Event name, Length: 794, dtype: object

# %%
df[df["Event name"].str.split('(').str.get(1).str.split(')').str.get(0) == 'POL']
# Out:
#          Year of event     Event dates  \
# 20173             2018  16.-17.03.2018
# 20174             2018  16.-17.03.2018
# 20175             2018  16.-17.03.2018
# 20176             2018  16.-17.03.2018
# 20177             2018  16.-17.03.2018
# ...                ...             ...
# 7431511           1995  23.-24.06.1995
# 7431512           1995  23.-24.06.1995
# 7431513           1995  23.-24.06.1995
# 7431514           1995  23.-24.06.1995
# 7431515           1995  23.-24.06.1995
#
#                                           Event name Event distance/length  \
# 20173     Setka Komandosa, Lubliniec - Kokotek (POL)                 100km
# 20174     Setka Komandosa, Lubliniec - Kokotek (POL)                 100km
# 20175     Setka Komandosa, Lubliniec - Kokotek (POL)                 100km
# 20176     Setka Komandosa, Lubliniec - Kokotek (POL)                 100km
# 20177     Setka Komandosa, Lubliniec - Kokotek (POL)                 100km
# ...

# %%
# combine all filters to get every run in 2020 in Poland

# %%
df[(df["Event distance/length"].isin(['50km', '50mi']))   & (df["Year of event"] == 2020) & (df["Event name"].str.split('(').str.get(1).str.split(')').str.get(0) == 'POL')]
# Out:
#          Year of event Event dates                                Event name  \
# 2583899           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split (POL)
# 2583900           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split (POL)
# 2583901           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split (POL)
# 2583902           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split (POL)
# 2583903           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split (POL)
# ...                ...         ...                                       ...
# 2762404           2020  03.10.2020                Bison Ultra-Trail 50 (POL)
# 2762405           2020  03.10.2020                Bison Ultra-Trail 50 (POL)
# 2762406           2020  03.10.2020                Bison Ultra-Trail 50 (POL)
# 2762407           2020  03.10.2020                Bison Ultra-Trail 50 (POL)
# 2762408           2020  03.10.2020                Bison Ultra-Trail 50 (POL)
#
# ...

# %%
df2 = df[(df["Event distance/length"].isin(['50km', '50mi']))   & (df["Year of event"] == 2020) & (df["Event name"].str.split('(').str.get(1).str.split(')').str.get(0) == 'POL')]

# %%
df2.shape
# Out:
# (510, 13)

# %%
# erase (POL) from all

# %%
df2["Event name"] = df2["Event name"].str.split('(').str.get(0)
# Out:
# c:\users\moham\onedrive\bureau\table\.venv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#          Year of event Event dates                           Event name  \
# 2583899           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# 2583900           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# 2583901           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# 2583902           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# 2583903           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2583899                  50km                         17           3:11:13 h
# 2583900                  50km                         17           3:24:00 h
# 2583901                  50km                         17           3:27:57 h
# 2583902                  50km                         17           3:35:53 h
# 2583903                  50km                         17           3:36:27 h
#
#                Athlete club Athlete country  Athlete year of birth  \
# ...

# %%
# erase columns

# %%
df2 = df2.drop(['Athlete club', 'Athlete country'], axis = 1)

# %%
df2.head()
# Out:
#          Year of event Event dates                           Event name  \
# 2583899           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# 2583900           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# 2583901           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# 2583902           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# 2583903           2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2583899                  50km                         17           3:11:13 h
# 2583900                  50km                         17           3:24:00 h
# 2583901                  50km                         17           3:27:57 h
# 2583902                  50km                         17           3:35:53 h
# 2583903                  50km                         17           3:36:27 h
#
#          Athlete year of birth Athlete gender Athlete age category  \
# ...

# %%
# clean null values

# %%
df2.isna().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete year of birth        1
# Athlete gender               0
# Athlete age category         1
# Athlete average speed        0
# Athlete ID                   0
# dtype: int64

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (509, 11)

# %%
# check dupes

# %%
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID]
# Index: []

# %%
# reset index

# %%
df2.reset_index(drop = True)
# Out:
#      Year of event Event dates                           Event name  \
# 0             2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# 1             2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# 2             2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# 3             2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# 4             2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split
# ..             ...         ...                                  ...
# 504           2020  03.10.2020                Bison Ultra-Trail 50
# 505           2020  03.10.2020                Bison Ultra-Trail 50
# 506           2020  03.10.2020                Bison Ultra-Trail 50
# 507           2020  03.10.2020                Bison Ultra-Trail 50
# 508           2020  03.10.2020                Bison Ultra-Trail 50
#
#     Event distance/length  Event number of finishers Athlete performance  \
# 0                    50km                         17           3:11:13 h
# ...

# %%
# fix types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
df2["Athlete average speed"] = df2["Athlete average speed"].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed        float64
# Athlete ID                     int64
# dtype: object

# %%
# rename columns

# %%
df2 = df2.rename(columns = {
    "Year of event"                : "Year",  
"Event dates"                  : "Dates",
"Event name"                  : "NameRace",
"Event distance/length"        : "Distance",
"Event number of finishers"    : "Num finishers",
"Athlete performance"         :"Perf",
"Athlete year of birth"       : "Birth",
"Athlete gender"              : "Gender",
"Athlete age category"         : "Category",
"Athlete average speed"       : "Speed",
"Athlete ID"                    : "ID"
    
})

# %%
df2.head()
# Out:
#          Year       Dates                             NameRace Distance  \
# 2583899  2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split      50km
# 2583900  2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split      50km
# 2583901  2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split      50km
# 2583902  2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split      50km
# 2583903  2020  06.06.2020  6 Godzin Pełnej Mocy - 50 Km Split      50km
#
#          Num finishers       Perf   Birth Gender Category   Speed      ID
# 2583899             17  3:11:13 h  1980.0      M      M40  15.689  214575
# 2583900             17  3:24:00 h  1982.0      F      W35  14.706   46487
# 2583901             17  3:27:57 h  1973.0      M      M45  14.427   19443
# 2583902             17  3:35:53 h  1979.0      M      M40  13.896   23609
# 2583903             17  3:36:27 h  1987.0      M      M23  13.860  303187

# %%
# compare
df3 = df.head(100)

# %%
sns.histplot(df3, x = "Event distance/length", hue = 'Athlete gender')
# Out:
# <AxesSubplot:xlabel='Event distance/length', ylabel='Count'>

# %%
sns.displot(df3[df3["Event distance/length"] == '50km']["Athlete average speed"])

# %%
# QUESTIONS

# %%
# difference of speed for 50km/mi for M and F

# %%
df3 = df3.dropna()

# %%
df3["Athlete average speed"] = df3["Athlete average speed"].astype(float)
# Out:
# c:\users\moham\onedrive\bureau\table\.venv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3.groupby(['Event distance/length', 'Athlete gender'])['Athlete average speed'].mean()
# Out:
# Event distance/length  Athlete gender
# 50km                   F                 6.487375
#                        M                 7.381667
# 50mi                   F                 6.523667
#                        M                 6.922333
# 63.9km                 F                 6.672000
#                        M                 6.942765
# 6h                     F                 8.458000
#                        M                 9.139000
# Name: Athlete average speed, dtype: float64

# %%
# CREATE SEASONS WITH MONTHS

# %%
df3.head(10)
# Out:
#     Year of event Event dates           Event name Event distance/length  \
# 0            2018  06.01.2018  Selva Costera (CHI)                  50km
# 1            2018  06.01.2018  Selva Costera (CHI)                  50km
# 2            2018  06.01.2018  Selva Costera (CHI)                  50km
# 3            2018  06.01.2018  Selva Costera (CHI)                  50km
# 4            2018  06.01.2018  Selva Costera (CHI)                  50km
# 6            2018  06.01.2018  Selva Costera (CHI)                  50km
# 7            2018  06.01.2018  Selva Costera (CHI)                  50km
# 8            2018  06.01.2018  Selva Costera (CHI)                  50km
# 9            2018  06.01.2018  Selva Costera (CHI)                  50km
# 10           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#     Event number of finishers Athlete performance         Athlete club  \
# 0                          22           4:51:39 h                Tnfrc
# ...

# %%
df["months"] = df["Event dates"].str.split(".").str.get(1).astype(int)

# %%
df["seasons"] = df["months"].apply(lambda x: "Winter" if x > 11 else "Fall" if x > 8 else 'Summer' if x > 5 else "Spring" if x > 2 else "Winter")

# %%
df.head(720)
# Out:
#      Year of event Event dates  \
# 0             2018  06.01.2018
# 1             2018  06.01.2018
# 2             2018  06.01.2018
# 3             2018  06.01.2018
# 4             2018  06.01.2018
# ..             ...         ...
# 715           2018  24.03.2018
# 716           2018  24.03.2018
# 717           2018  24.03.2018
# 718           2018  24.03.2018
# 719           2018  24.03.2018
#
#                                             Event name Event distance/length  \
# 0                                  Selva Costera (CHI)                  50km
# 1                                  Selva Costera (CHI)                  50km
# 2                                  Selva Costera (CHI)                  50km
# 3                                  Selva Costera (CHI)                  50km
# 4                                  Selva Costera (CHI)                  50km
# ..                                                 ...                   ...
# ...
